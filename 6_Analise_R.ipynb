# %% [markdown]
# # Analisando Tweets: Dental Implants - Atualizado

# %%
# carregando bibliotecas
library("RPostgreSQL")
library("ggplot2")
library("zoo")

# configurações PostgreSQL
db_server="kode.ffclrp.usp.br"
db_port="5432"
db_user=""
db_password=""
db_name="twitter"

# carregando configurações PostgreSQL do arquivo
source("conf.R")

# conectando com o banco de dados
drv <- dbDriver("PostgreSQL")
con <- dbConnect(drv, dbname = db_name,
                 host = db_server, port = db_port,
                 user = db_user, password = db_password)
# Out:
# Loading required package: DBI

# %% [markdown]
# ## Tweets por dia:

# %%
twsDia <- dbGetQuery(con, paste("SELECT " ,
                          "t.datatweet, " ,
                          "count(t.codtweet) AS tweet ",
                          "FROM tweet t " ,
                          "INNER JOIN amostratweet at ON at.codtweet = t.codtweet ",
                          "WHERE at.codamostra = 219 " ,
                          "GROUP BY 1" ,
                          "ORDER BY 1"))
saveRDS(twsDia, file = "data/twsDia2020.rds")

# %%
twsDia
# Out:
#      datatweet  tweet
# 1    2016-07-12  99
# 2    2016-07-13 298
# 3    2016-07-14 328
# 4    2016-07-15 345
# 5    2016-07-16 311
# 6    2016-07-17 234
# 7    2016-07-18 407
# 8    2016-07-19 618
# 9    2016-07-20 291
# 10   2016-07-21 399
# 11   2016-07-22 554
# 12   2016-07-23 266
# 13   2016-07-24 259
# 14   2016-07-25 440
# 15   2016-07-26 383
# 16   2016-07-27 305
# 17   2016-07-28 309
# 18   2016-07-29 300
# 19   2016-07-30 163
# 20   2016-07-31 157
# 21   2016-08-01 305
# 22   2016-08-02 471
# 23   2016-08-03 232
# 24   2016-08-04 384
# 25   2016-08-05 228
# 26   2016-08-06 266
# 27   2016-08-07 102
# 28   2016-08-08 336
# 29   2016-08-09 397
# 30   2016-08-10 470
# ⋮    ⋮          ⋮
# 1093 2019-11-03  82
# 1094 2019-11-04 132
# 1095 2019-11-05 139
# 1096 2019-11-06 144
# 1097 2019-11-07 150
# 1098 2019-11-08 155
# 1099 2019-11-09 114
# 1100 2019-11-10 105
# 1101 2019-11-11 107
# 1102 2019-11-12 149
# 1103 2019-11-13 151
# 1104 2019-11-14 202
# 1105 2019-11-15 172
# 1106 2019-11-16  86
# 1107 2019-11-17 117
# 1108 2019-11-18 168
# 1109 2019-11-19 160
# 1110 2019-11-20 159
# 1111 2019-11-21 150
# 1112 2019-11-22 173
# 1113 2019-11-23  95
# 1114 2019-11-24  75
# 1115 2019-11-25 166
# 1116 2019-11-26 158
# 1117 2019-11-27 224
# 1118 2019-11-28 151
# 1119 2019-11-29 108
# 1120 2019-11-30  87
# 1121 2019-12-01  79
# 1122 2019-12-02 136

# %%
ggplot(data = twsDia, aes(x = datatweet, y = tweet, fill = tweet )) +
  geom_bar(stat = "identity") +
  theme(legend.position = "none", axis.text.x = element_text(angle = 45, hjust = 1)) +
  scale_fill_gradient(low = "#56B1F7", high = "red")+
  xlab("Data") + 
  ylab("Tweets") + 
  ggtitle("Tweets por dia")
# Out:
# plot without title

# %%
summary(twsDia)
# Out:
#    datatweet              tweet
#  Min.   :2016-07-12   Min.   :   2.0
#  1st Qu.:2017-04-20   1st Qu.: 168.0
#  Median :2018-01-27   Median : 242.0
#  Mean   :2018-03-09   Mean   : 267.4
#  3rd Qu.:2019-02-07   3rd Qu.: 310.0
#  Max.   :2019-12-02   Max.   :1672.0

# %%
twsDia$Tempo.Dia <- as.Date(twsDia$datatweet,'%d/%m/%Y')
twsDia$Quantidade.de.tweets <- twsDia$tweet

# %%
g<-ggplot(twsDia,aes(x=Tempo.Dia,y=Quantidade.de.tweets,group=1))+
            geom_line()+
            geom_smooth()
g
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# ## Tweets por mês:

# %%
twsMes <- dbGetQuery(con, paste("SELECT " ,
                          "to_char(datatweet, 'YYYY-MM') as datatweet, " ,
                          "count(t.codtweet) AS tweet " ,
                          "FROM tweet t " ,
                          "INNER JOIN amostratweet at ON at.codtweet = t.codtweet ",
                          "WHERE at.codamostra = 219 " ,
                          "GROUP BY 1" ,
                          "ORDER BY 1"))
saveRDS(twsMes, file = "data/twsMes2020.rds")

# %%
twsMes
# Out:
#    datatweet tweet
# 1  2016-07    6466
# 2  2016-08    9534
# 3  2016-09    7855
# 4  2016-10    9159
# 5  2016-11    8417
# 6  2016-12   14716
# 7  2017-01   15087
# 8  2017-02    8633
# 9  2017-03   11443
# 10 2017-04    8030
# 11 2017-05    8592
# 12 2017-06    9090
# 13 2017-07    8518
# 14 2017-08    7772
# 15 2017-09    8623
# 16 2017-10    9597
# 17 2017-11    9571
# 18 2017-12    8689
# 19 2018-01    7167
# 20 2018-02    6926
# 21 2018-03    7470
# 22 2018-04    6471
# 23 2018-05    1732
# 24 2018-07    1677
# 25 2018-08    3163
# 26 2018-09    6345
# 27 2018-10    8322
# 28 2018-11    6232
# 29 2018-12    7155
# 30 2019-01    8306
# 31 2019-02   10341
# 32 2019-03    6207
# 33 2019-04    6308
# 34 2019-05    5870
# 35 2019-06    6867
# 36 2019-07    5746
# 37 2019-08    4525
# 38 2019-09    4846
# 39 2019-10    4222
# 40 2019-11    4082
# 41 2019-12     215

# %%
ggplot(data = twsMes, aes(x = datatweet, y = tweet, fill = tweet )) +
  geom_bar(stat = "identity") +
  theme(legend.position = "none", axis.text.x = element_text(angle = 45, hjust = 1)) +
  scale_fill_gradient(low = "#56B1F7", high = "red")+
  xlab("Data") + 
  ylab("Tweets") + 
  ggtitle("Tweets por mês")
# Out:
# plot without title

# %%
summary(twsMes)
# Out:
#   datatweet             tweet
#  Length:41          Min.   :  215
#  Class :character   1st Qu.: 6207
#  Mode  :character   Median : 7470
#                     Mean   : 7317
#                     3rd Qu.: 8633
#                     Max.   :15087

# %%
twsMes$mes <- as.yearmon(twsMes$datatweet)
twsMes$Quantidade.de.tweets <- twsMes$tweet

# %%
g<-ggplot(twsMes,aes(x=mes,y=Quantidade.de.tweets,group=1))+
            geom_line()+
            geom_smooth()
g
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
twsPais <- dbGetQuery(con, paste("SELECT " ,
                          "local1 as pais, " ,
                          "count(t.codtweet) AS tweet FROM tweet t " ,
                          "inner join amostratweet at on at.codtweet = t.codtweet ",
                          "where at.codamostra = 219 and local1 <> '' ",
                          "GROUP BY 1" ,
                          "ORDER BY 2 desc"))
saveRDS(twsPais, file = "data/twsPais")

# %%
twsPais
# Out:
#    pais                        tweet
# 1  United States               1803
# 2  United Kingdom               419
# 3  India                        361
# 4  Canada                       115
# 5  Australia                    105
# 6  Kingdom of Saudi Arabia       33
# 7  United Arab Emirates          26
# 8  Republic of the Philippines   23
# 9  Ireland                       19
# 10 Costa Rica                    19
# 11 Mexico                        19
# 12 Bahrain                       18
# 13 Malaysia                      17
# 14 Estados Unidos                16
# 15 Việt Nam                      16
# 16 Indonesia                     15
# 17 South Africa                  14
# 18 Portugal                      13
# 19 Pakistan                      13
# 20 Türkiye                       13
# 21 中华人民共和国                11
# 22 Ghana                         11
# 23 Nigeria                       10
# 24 Lebanon                        9
# 25 भारत                           8
# 26 Greece                         7
# 27 Singapore                      7
# 28 Turkey                         7
# 29 New Zealand                    6
# 30 المملكة العربية السعودية       5
# ⋮  ⋮                           ⋮
# 59 Peru                        2
# 60 Qatar                       2
# 61 Sverige                     2
# 62 Brasil                      2
# 63 Bahamas                     2
# 64 Украина                     2
# 65 ประเทศไทย                   2
# 66 Taiwan                      1
# 67 新加坡                      1
# 68 Nicaragua                   1
# 69 Colombia                    1
# 70 Espanya                     1
# 71 Belgium                     1
# 72 Magyarország                1
# 73 Venezuela                   1
# 74 Danmark                     1
# 75 Georgia                     1
# 76 Zambia                      1
# 77 Deutschland                 1
# 78 Κύπρος                      1
# 79 Россия                      1
# 80 Ecuador                     1
# 81 الامارات العربية المتحدة    1
# 82 Dominican Republic          1
# 83 دولة الكويت                 1
# 84 Republic of Croatia         1
# 85 Brazil                      1
# 86 Polska                      1
# 87 Hungary                     1
# 88 Switzerland                 1

# %%
twsIdiomas <- dbGetQuery(con, paste("SELECT " ,
                          "json->>'lang' as idioma, count(t.codtweet) as quantidade" ,
                          "from tweet t",
                          "inner join amostratweet at on at.codtweet = t.codtweet ",
                          "where at.codamostra = 218 ",
                          "GROUP BY 1" ,
                          "ORDER BY 2 desc"))
saveRDS(twsIdiomas, file = "data/twsIdiomas")

# %%
twsIdiomas
# Out:
#    idioma quantidade
# 1  en     299987
# 2  ja      10083
# 3  und      5538
# 4  fr       2053
# 5  ca       1701
# 6  de       1027
# 7  es        828
# 8  da        816
# 9  ro        618
# 10 tr        522
# 11 ar        346
# 12 in        238
# 13 tl        181
# 14 it        135
# 15 cy        111
# 16 pt         85
# 17 ko         78
# 18 cs         74
# 19 vi         55
# 20 ru         47
# 21 eu         46
# 22 no         45
# 23 zh         42
# 24 th         32
# 25 et         22
# 26 nl         21
# 27 ht         21
# 28 hu         19
# 29 pl         13
# 30 sv         11
# 31 sl          9
# 32 hi          7
# 33 ur          4
# 34 ne          3
# 35 el          3
# 36 my          2
# 37 bn          2
# 38 NA          1
# 39 gu          1
# 40 lt          1
# 41 fi          1
# 42 fa          1
# 43 bg          1

# %%
# Out:
#    datatweet tweet
# 1  2016-07    6466
# 2  2016-08    9534
# 3  2016-09    7855
# 4  2016-10    9159
# 5  2016-11    8417
# 6  2016-12   14716
# 7  2017-01   15087
# 8  2017-02    8633
# 9  2017-03   11443
# 10 2017-04    8030
# 11 2017-05    8592
# 12 2017-06    9090
# 13 2017-07    8518
# 14 2017-08    7772
# 15 2017-09    8623
# 16 2017-10    9597
# 17 2017-11    9571
# 18 2017-12    8689
# 19 2018-01    7167
# 20 2018-02    6926
# 21 2018-03    7470
# 22 2018-04    6471
# 23 2018-05    1732
# 24 2018-07    1677
# 25 2018-08    3163
# 26 2018-09    6345
# 27 2018-10    8322
# 28 2018-11    6232
# 29 2018-12    7155
# 30 2019-01    8306
# 31 2019-02   10341
# 32 2019-03    6207
# 33 2019-04    6308
# 34 2019-05    5870
# 35 2019-06    6867
# 36 2019-07    5746
# 37 2019-08    4525
# 38 2019-09    4846
# 39 2019-10    4222
# 40 2019-11    4082
# 41 2019-12     215
